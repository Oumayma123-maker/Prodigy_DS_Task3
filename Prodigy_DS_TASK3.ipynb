# %%
import pandas as pd
data = pd.read_csv("bank-additional-full.csv",delimiter=';')
data.rename(columns={'y':'deposit'}, inplace=True)
data
# Out:
#        age          job  marital            education  default housing loan  \
# 0       56    housemaid  married             basic.4y       no      no   no
# 1       57     services  married          high.school  unknown      no   no
# 2       37     services  married          high.school       no     yes   no
# 3       40       admin.  married             basic.6y       no      no   no
# 4       56     services  married          high.school       no      no  yes
# ...    ...          ...      ...                  ...      ...     ...  ...
# 41183   73      retired  married  professional.course       no     yes   no
# 41184   46  blue-collar  married  professional.course       no      no   no
# 41185   56      retired  married    university.degree       no     yes   no
# 41186   44   technician  married  professional.course       no      no   no
# 41187   74      retired  married  professional.course       no     yes   no
#
# ...

# %%
data.shape
# Out:
# (41188, 21)

# %%
data.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx',
#        'cons.conf.idx', 'euribor3m', 'nr.employed', 'deposit'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41188 entries, 0 to 41187
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41188 non-null  int64
#  1   job             41188 non-null  object
#  2   marital         41188 non-null  object
#  3   education       41188 non-null  object
#  4   default         41188 non-null  object
#  5   housing         41188 non-null  object
#  6   loan            41188 non-null  object
#  7   contact         41188 non-null  object
#  8   month           41188 non-null  object
#  9   day_of_week     41188 non-null  object
#  10  duration        41188 non-null  int64
#  11  campaign        41188 non-null  int64
#  12  pdays           41188 non-null  int64
#  13  previous        41188 non-null  int64
#  14  poutcome        41188 non-null  object
#  15  emp.var.rate    41188 non-null  float64
#  16  cons.price.idx  41188 non-null  float64
# ...

# %%
data.describe()
# Out:
#                age      duration      campaign         pdays      previous  \
# count  41188.00000  41188.000000  41188.000000  41188.000000  41188.000000
# mean      40.02406    258.285010      2.567593    962.475454      0.172963
# std       10.42125    259.279249      2.770014    186.910907      0.494901
# min       17.00000      0.000000      1.000000      0.000000      0.000000
# 25%       32.00000    102.000000      1.000000    999.000000      0.000000
# 50%       38.00000    180.000000      2.000000    999.000000      0.000000
# 75%       47.00000    319.000000      3.000000    999.000000      0.000000
# max       98.00000   4918.000000     56.000000    999.000000      7.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx     euribor3m   nr.employed
# count  41188.000000    41188.000000   41188.000000  41188.000000  41188.000000
# mean       0.081886       93.575664     -40.502600      3.621291   5167.035911
# ...

# %%
#checking for NULL/Missing values in the dataset :
data.isnull().sum()
# Out:
# age               0
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           0
# month             0
# day_of_week       0
# duration          0
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# emp.var.rate      0
# cons.price.idx    0
# cons.conf.idx     0
# euribor3m         0
# nr.employed       0
# deposit           0
# dtype: int64

# %%
# Checking for duplicate values in the dataset :
data.duplicated().sum()
# Out:
# 12

# %%
data.drop_duplicates(inplace=True)

# %%
data.duplicated().sum()
# Out:
# 0

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# List of categorical columns to visualize (adjust based on your data)
categorical_cols = ['job', 'marital', 'education', 'housing', 'loan', 'contact', 'day_of_week', 'month', 'poutcome', 'default', 'deposit']

# Set up the figure for subplots
plt.figure(figsize=(20, 15))

# Set Seaborn style and context for better aesthetics
sns.set(style="whitegrid", context="notebook")

# Generate a color palette with a number of distinct colors
palette = sns.color_palette("husl", n_colors=len(categorical_cols))

# Loop through the categorical columns and create a subplot for each
for i, col in enumerate(categorical_cols, 1):
    plt.subplot(3, 4, i)
    sns.countplot(x=col, data=data, palette=palette)
    plt.title(f'Distribution of {col}')
    plt.xticks(rotation=45)

# Adjust layout
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-22-59c023e0d594>:20: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=col, data=data, palette=palette)
# <ipython-input-22-59c023e0d594>:20: UserWarning:
# The palette list has fewer values (11) than needed (12) and will cycle, which may produce an uninterpretable plot.
#   sns.countplot(x=col, data=data, palette=palette)
# <ipython-input-22-59c023e0d594>:20: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=col, data=data, palette=palette)
# <ipython-input-22-59c023e0d594>:20: UserWarning: The palette list has more values (11) than needed (4), which may not be intended.
#   sns.countplot(x=col, data=data, palette=palette)
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# List of numeric columns to visualize (adjust based on your data)
numeric_cols = [
    'age',  'duration', 'campaign', 'pdays', 'previous',
    'emp.var.rate', 'cons.price.idx', 'cons.conf.idx', 'euribor3m', 'nr.employed'
]

# Set up the figure for subplots
plt.figure(figsize=(20, 15))  # Adjust size based on number of plots

# Set Seaborn style and context for better aesthetics
sns.set(style="whitegrid", context="notebook")

# Define a color palette (if needed)
palette = sns.color_palette("husl", n_colors=len(numeric_cols))

# Loop through the numeric columns and create a subplot for each
for i, col in enumerate(numeric_cols, 1):
    plt.subplot(4, 4, i)  # Creates a 4-row, 4-column layout of subplots
    sns.histplot(data[col], kde=True, color=palette[i % len(palette)], bins=30)  # KDE for density plot
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')

# Adjust layout
plt.tight_layout()
plt.show()

# %%
data.plot(kind='box', subplots=True, layout=(5,2), figsize=(10,30))
plt.show()

# %%
import numpy as np
columns = ['age', 'campaign', 'duration']

for column in columns:
    q1 = np.percentile(data[column], 25)
    q3 = np.percentile(data[column], 75)
    iqr = q3 - q1
    lower_bound = q1 - 1.5 * iqr
    upper_bound = q3 + 1.5 * iqr
    # Filter the DataFrame for the current column
    df = data[(data[column] >= lower_bound) & (data[column] <= upper_bound)]

# %%
#convert categorical variables to numeric :
from sklearn.preprocessing import LabelEncoder
label_encoders = {}
for column in data.select_dtypes(include=['object']).columns:
    label_encoders[column]=LabelEncoder()
    data[column]=label_encoders[column].fit_transform(data[column])

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report,confusion_matrix
x = data.drop('deposit', axis=1)
y = data['deposit']
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=0)
tree =DecisionTreeClassifier()
tree.fit(x_train, y_train)
#fitting our model
y_pred_train=tree.predict(x_train)
print("Training accuracy:{}".format(accuracy_score(y_train, y_pred_train)))
y_pred=tree.predict(x_test)
print("Testing accuracy:{}".format(accuracy_score(y_test, y_pred)))
#Evaluating Prediction Accuracy
print("accuracy :",accuracy_score(y_test,y_pred))
#Classification Report
print("Classificatio Report :\n", classification_report(y_test, y_pred))
#Matrix Confusion
print("Matrix Confusion :\n", confusion_matrix(y_test, y_pred))
# Out:
# Training accuracy:1.0
# Testing accuracy:0.885016998542982
# accuracy : 0.885016998542982
# Classificatio Report :
#                precision    recall  f1-score   support
#
#            0       0.93      0.94      0.94      7269
#            1       0.51      0.49      0.50       967
#
#     accuracy                           0.89      8236
#    macro avg       0.72      0.71      0.72      8236
# weighted avg       0.88      0.89      0.88      8236
#
# Matrix Confusion :
#  [[6815  454]
#  [ 493  474]]

# %% [markdown]
# Having a training accuracy of 1.0 (100%) and a testing accuracy of 0.88 (88%) suggests that my model is performing well on the test data but might be overfitting on the training data. Overfitting occurs when the model learns the training data too well, including its noise and outliers, which can result in reduced performance on new, unseen data.

# %%
tree = DecisionTreeClassifier(max_depth=5, min_samples_split=10, min_samples_leaf=5)

# %%
from sklearn.model_selection import cross_val_score

scores = cross_val_score(tree, x, y, cv=5)
print("Cross-Validation Scores: ", scores)
print("Mean CV Accuracy: {:.2f}".format(scores.mean()))
# Out:
# Cross-Validation Scores:  [0.88853813 0.35446266 0.8486946  0.20643594 0.1428051 ]
# Mean CV Accuracy: 0.49

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {
    'max_depth': [3, 5, 7, 10],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 5]
}
grid_search = GridSearchCV(DecisionTreeClassifier(), param_grid, cv=5, scoring='accuracy')
grid_search.fit(x_train, y_train)
print("Best Parameters: ", grid_search.best_params_)
# Out:
# Best Parameters:  {'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 2}

# %%
# Re-train the model
tree = DecisionTreeClassifier(max_depth=5, min_samples_split=2, min_samples_leaf=1)
tree.fit(x_train, y_train)

# Predict and evaluate
y_pred = tree.predict(x_test)
print("New Accuracy Score: {:.2f}".format(accuracy_score(y_test, y_pred)))
print("New Classification Report:\n", classification_report(y_test, y_pred))
print("New Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
# Out:
# New Accuracy Score: 0.91
# New Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.96      0.95      7269
#            1       0.66      0.55      0.60       967
#
#     accuracy                           0.91      8236
#    macro avg       0.80      0.75      0.77      8236
# weighted avg       0.91      0.91      0.91      8236
#
# New Confusion Matrix:
#  [[6992  277]
#  [ 439  528]]

# %%
from sklearn.tree import plot_tree
feature_names=df.columns.tolist()
plt.figure(figsize=(40,20))
class_names=["class_0","class_1"]
plot_tree(tree, feature_names=feature_names, class_names=class_names, filled=True,fontsize=12)
plt.title("Decision Tree")
plt.show()
